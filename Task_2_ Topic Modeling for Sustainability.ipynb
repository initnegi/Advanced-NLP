# %% [markdown]
# ## Task 2: Topic Modeling
#
# This task involves identifying key topics within a dataset of sustainability-related reviews and tweets using Latent Dirichlet Allocation (LDA). The primary goal was to uncover recurring themes such as environmental conservation, climate change, and recycling. Text preprocessing steps like tokenization and stopword removal were applied to prepare the data for modeling, followed by topic visualization to analyze the results.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install nltk sklearn matplotlib seaborn

# %% [markdown]
# # Import necessary Libraries

# %%
import pandas as pd
import re
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Load the dataset
df = pd.read_csv("/content/drive/My Drive/Advanced NLP/Dataset/twitter_dataset.csv", encoding ="ISO-8859-1" , names=["target", "ids", "date", "flag", "user", "text"])

df.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   target  1600000 non-null  int64
#  1   ids     1600000 non-null  int64
#  2   date    1600000 non-null  object
#  3   flag    1600000 non-null  object
#  4   user    1600000 non-null  object
#  5   text    1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
df["target"].value_counts()
# Out:
# target
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %% [markdown]
# ## Removing unecessary columns

# %%
df.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# We are only interested in the target and text columns, the rest will be removed

# %%
df = df[["text", "target"]]

# %% [markdown]
# # Let's extract tweets that are related to sustainability

# %%
# We defined a set of sustainability-related keywords
sustainability_keywords = [
    'climate change', 'renewable energy', 'clean energy', 'sustainable', 'green energy',
    'carbon emissions', 'environment', 'recycling', 'solar power', 'wind energy', 'sustainability',
    'biofuel', 'global warming', 'sustainable transport', 'fossil fuels', 'net zero', 'greenhouse gases',
    'carbon footprint', 'conservation', 'pollution'
]

# %%
# Now we will filter rows that contain any of the sustainability-related keywords in the 'text' column
def contains_sustainability_keywords(text):
    text = text.lower()  # Convert text to lowercase for case-insensitive matching
    return any(keyword in text for keyword in sustainability_keywords)

# %%
# Filter out rows containing sustainability-related keywords
sustainability_related_df = df[df['text'].apply(contains_sustainability_keywords)]

# %%
print(f"Sustainability Related DF contains {len(sustainability_related_df)}")
# Out:
# Sustainability Related DF contains 493

# %%
# Download nltk data
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
df = sustainability_related_df

# %% [markdown]
# # Text Preprocessing

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
from nltk.corpus import stopwords

lemmatizer = WordNetLemmatizer()

# Clean the text: remove URLs, users, special chars stopwords etc
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"
stop_words = stopwords.words("english")
stop_words.extend(['today', 'good', 'like', 'gt', 'amp', 'quot'])

def preprocess(text):
    # Remove unwanted characters and lemmatize
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    tokens = [lemmatizer.lemmatize(token) for token in text.split() if token not in stop_words]
    return " ".join(tokens)

df["cleaned_text"] = df.text.apply(preprocess)

# %%
pd.set_option('display.max_colwidth', None)

df.head()
# Out:
#                                                                                                                                           text  \
# 335   getting annoyed easily today  &gt;&gt;&gt; biofuel proposal: getting annoyed easily today  &gt;&gt;&gt; biof.. http://tinyurl.com/ceprvs
# 3363                                                                                Gosh  It is raining in summer cause of the global warming?
# 3862   Arse, totally forgot about a webinar that I wanted to attend this morning. Now I'll never know how to secure virtualised environments
# 4722                                                http://twitpic.com/2ya1c - Good F'in Morning  Springtime my ass. Global warming?! Suck it!
# 6254                                                                                    I hate global warming and i hate snow. ITS APRIL ffs.
#
#       target  \
# 335        0
# 3363       0
# 3862       0
# 4722       0
# 6254       0
#
#                                                                                      cleaned_text
# 335                           getting annoyed easily biofuel proposal getting annoyed easily biof
# 3363                                                     gosh raining summer cause global warming
# 3862  arse totally forgot webinar wanted attend morning never know secure virtualised environment
# 4722                                                  f morning springtime as global warming suck
# 6254                                                      hate global warming hate snow april ffs

# %% [markdown]
# ## Tokenization and Vectorization

# %%
# Tokenization and Vectorization
vectorizer = CountVectorizer(max_df=0.9, min_df=2, stop_words='english')
dtm = vectorizer.fit_transform(df['cleaned_text'])

# %% [markdown]
# # LDA Model Training

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Set the number of topics
num_topics = 5

# Create and train the LDA model
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %% [markdown]
# # Extracting the Topics

# %%
# Get the vocabulary
terms = vectorizer.get_feature_names_out()

# %%
# terms

# %%
# Display the top words for each topic
def display_topics(model, feature_names, num_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-num_top_words - 1:-1]]))

# Display the top 10 words for each topic
num_top_words = 10
display_topics(lda, terms, num_top_words)
# Out:
# Topic 1:
# environment day work environmentally sorry safe save solar time conservation
# Topic 2:
# change pollution climate environmental know new recycling let lot project
# Topic 3:
# recycling environment environmental warming solar global day power morning people
# Topic 4:
# global warming environment thing think weather summer new work carbon
# Topic 5:
# global warming recycling environmental going weather hate really coffee got

# %% [markdown]
# # Summary of the Identified Topics

# %%
topic_summaries = []
for topic_idx, topic in enumerate(lda.components_):
    top_words = [terms[i] for i in topic.argsort()[:-num_top_words - 1:-1]]
    summary = f"Topic {topic_idx + 1}: This topic focuses on {', '.join(top_words[:5])} and related themes."
    topic_summaries.append(summary)

# Print topic summaries
for summary in topic_summaries:
    print(summary)
# Out:
# Topic 1: This topic focuses on environment, day, work, environmentally, sorry and related themes.
# Topic 2: This topic focuses on change, pollution, climate, environmental, know and related themes.
# Topic 3: This topic focuses on recycling, environment, environmental, warming, solar and related themes.
# Topic 4: This topic focuses on global, warming, environment, thing, think and related themes.
# Topic 5: This topic focuses on global, warming, recycling, environmental, going and related themes.

# %% [markdown]
# # Visualizing the Topic Distribution

# %%
import plotly.express as px

# Get the topic distribution for each document
doc_topic_dist = lda.transform(dtm)

# %%
import plotly.express as px
import pandas as pd

# Get the dominant topic for each document
doc_topics = doc_topic_dist.argmax(axis=1)

# Create a DataFrame for Plotly
df_plot = pd.DataFrame(doc_topics, columns=['Topic'])

# Map numeric topics to "Topic 1", "Topic 2", etc.
df_plot['Topic'] = df_plot['Topic'].apply(lambda x: f'Topic {x + 1}')

# Plot using Plotly
fig = px.histogram(df_plot, x='Topic', title='Distribution of Topics in Documents',
                   labels={'Topic': 'Topics'},
                   text_auto=True)

# Update layout for better appearance
fig.update_layout(xaxis_title='Topics',
                  yaxis_title='Number of Documents',
                  title_x=0.5)

# Show interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e16562b8-8518-434f-bffe-e43aeb9a5489" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e16562b8-8518-434f-bffe-e43aeb9a5489")) {                    Plotly.newPlot(                        "e16562b8-8518-434f-bffe-e43aeb9a5489",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Topics=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"texttemplate":"%{value}","x":["Topic 4","Topic 4","Topic 3","Topic 4","Topic 5","Topic 1","Topic 3","Topic 4","Topic 4","Topic 2","Topic 4","Topic 5","Topic 3","Topic 1","Topic 4","Topic 5","Topic 5","Topic 2","Topic 4","Topic 5","Topic 5","Topic 4","Topic 4","Topic 2","Topic 2","Topic 1","Topic 4","Topic 3","Topic 4","Topic 4","Topic 3","Topic 4","Topic 1","Topic 2","Topic 2","Topic 1","Topic 2","Topic 1","Topic 5","Topic 4","Topic 4","Topic 1","Topic 3","Topic 5","Topic 4","Topic 5","Topic 3","Topic 5","Topic 3","Topic 4","Topic 5","Topic 4","Topic 3","Topic 5","Topic 2","Topic 2","Topic 3","Topic 4","Topic 3","Topic 2","Topic 1","Topic 4","Topic 4","Topic 2","Topic 4","Topic 1","Topic 2","Topic 4","Topic 2","Topic 4","Topic 2","Topic 2","Topic 2","Topic 2","Topic 4","Topic 3","Topic 3","Topic 2","Topic 2","Topic 1","Topic 4","Topic 4","Topic 4","Topic 3","Topic 2","Topic 5","Topic 3","Topic 3","Topic 2","Topic 4","Topic 4","Topic 2","Topic 3","Topic 3","Topic 4","Topic 2","Topic 3","Topic 2","Topic 1","Topic 2","Topic 1","Topic 4","Topic 2","Topic 5","Topic 4","Topic 5","Topic 5","Topic 5","Topic 1","Topic 2","Topic 5","Topic 4","Topic 5","Topic 4","Topic 4","Topic 5","Topic 4","Topic 1","Topic 3","Topic 4","Topic 2","Topic 4","Topic 4","Topic 1","Topic 5","Topic 2","Topic 5","Topic 4","Topic 4","Topic 2","Topic 3","Topic 1","Topic 3","Topic 4","Topic 5","Topic 2","Topic 1","Topic 2","Topic 1","Topic 3","Topic 3","Topic 4","Topic 4","Topic 1","Topic 4","Topic 5","Topic 2","Topic 2","Topic 1","Topic 4","Topic 3","Topic 3","Topic 3","Topic 4","Topic 5","Topic 1","Topic 3","Topic 3","Topic 3","Topic 2","Topic 4","Topic 4","Topic 5","Topic 3","Topic 1","Topic 3","Topic 2","Topic 3","Topic 5","Topic 5","Topic 1","Topic 2","Topic 2","Topic 2","Topic 4","Topic 4","Topic 3","Topic 3","Topic 3","Topic 2","Topic 2","Topic 2","Topic 5","Topic 4","Topic 5","Topic 4","Topic 4","Topic 3","Topic 4","Topic 2","Topic 3","Topic 3","Topic 2","Topic 5","Topic 4","Topic 4","Topic 1","Topic 1","Topic 2","Topic 1","Topic 2","Topic 1","Topic 1","Topic 1","Topic 4","Topic 4","Topic 4","Topic 3","Topic 3","Topic 3","Topic 1","Topic 4","Topic 1","Topic 4","Topic 5","Topic 1","Topic 3","Topic 4","Topic 4","Topic 1","Topic 1","Topic 3","Topic 3","Topic 4","Topic 4","Topic 1","Topic 1","Topic 4","Topic 2","Topic 5","Topic 4","Topic 4","Topic 5","Topic 4","Topic 4","Topic 2","Topic 1","Topic 1","Topic 5","Topic 2","Topic 3","Topic 4","Topic 2","Topic 4","Topic 2","Topic 1","Topic 3","Topic 1","Topic 1","Topic 4","Topic 4","Topic 2","Topic 1","Topic 4","Topic 4","Topic 4","Topic 4","Topic 2","Topic 1","Topic 3","Topic 1","Topic 1","Topic 5","Topic 1","Topic 4","Topic 1","Topic 2","Topic 4","Topic 1","Topic 2","Topic 2","Topic 2","Topic 1","Topic 4","Topic 2","Topic 4","Topic 3","Topic 3","Topic 2","Topic 5","Topic 1","Topic 4","Topic 2","Topic 4","Topic 5","Topic 5","Topic 3","Topic 1","Topic 2","Topic 2","Topic 2","Topic 2","Topic 2","Topic 2","Topic 4","Topic 1","Topic 1","Topic 2","Topic 5","Topic 4","Topic 4","Topic 5","Topic 3","Topic 1","Topic 4","Topic 1","Topic 1","Topic 4","Topic 5","Topic 1","Topic 2","Topic 5","Topic 2","Topic 3 ...
